# %% [markdown]
# <a href="https://colab.research.google.com/github/gunner55/graph-intent/blob/main/Fitness_Intent_Graph_Draw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()

# %%
G.add_nodes_from(['Fitness', 'Group','Club', 'Class','Gym','Program','Center','Centre','Community','Team','Studio','Intent'])
G.number_of_nodes()
# Out:
# 12

# %%
G.add_edges_from([('Fitness', 'Group'), ('Fitness', 'Club'),('Fitness','Class'),('Fitness','Gym'),('Fitness','Program'),('Fitness','Center'),('Fitness','Center'),('Fitness','Centre'),('Fitness','Community'),('Fitness','Team'),('Fitness','Studio'),('Group','Intent'),('Club','Intent'),('Class','Intent'),('Gym','Intent'),('Program','Intent'),('Center','Intent'),('Centre','Intent'),('Community','Intent'),('Team','Intent'),('Studio','Intent')])
G.number_of_edges()
12
# Out:
# 12

# %%
#Draw the intent graph
nx.draw(G,with_labels = True)
